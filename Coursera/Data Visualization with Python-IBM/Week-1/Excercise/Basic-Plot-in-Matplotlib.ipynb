# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt.plot(5, 5, 'o')
plt.show()

# %%
plt.plot(5, 5, 'o')
plt.ylabel('Y-Label')
plt.xlabel('X-Label')
plt.title('Ploting Example')

plt.show()
