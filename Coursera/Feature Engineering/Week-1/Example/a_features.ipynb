# %% [markdown]
# # Trying out features

# %% [markdown]
# **Learning Objectives:**
#   * Improve the accuracy of a model by adding new features with the appropriate representation

# %% [markdown]
# The data is based on 1990 census data from California. This data is at the city block level, so these features reflect the total number of rooms in that block, or the total number of people who live on that block, respectively.

# %% [markdown]
# ## Set Up
# In this first cell, we'll load the necessary libraries.

# %%
import math
import shutil
import numpy as np
import pandas as pd
import tensorflow as tf

print(tf.__version__)
tf.logging.set_verbosity(tf.logging.INFO)
pd.options.display.max_rows = 10
pd.options.display.float_format = '{:.1f}'.format
# Out:
# /usr/local/envs/py2env/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 1.8.0

# %% [markdown]
# Next, we'll load our data set.

# %%
df = pd.read_csv("https://storage.googleapis.com/ml_universities/california_housing_train.csv", sep=",")

# %% [markdown]
# ## Examine and split the data
#
# It's a good idea to get to know your data a little bit before you work with it.
#
# We'll print out a quick summary of a few useful statistics on each column.
#
# This will include things like mean, standard deviation, max, min, and various quantiles.

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.3      34.2                15.0       5612.0          1283.0
# 1     -114.5      34.4                19.0       7650.0          1901.0
# 2     -114.6      33.7                17.0        720.0           174.0
# 3     -114.6      33.6                14.0       1501.0           337.0
# 4     -114.6      33.6                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0            1.5             66900.0
# 1      1129.0       463.0            1.8             80100.0
# 2       333.0       117.0            1.7             85700.0
# 3       515.0       226.0            3.2             73400.0
# 4       624.0       262.0            1.9             65500.0

# %%
df.describe()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# count    17000.0   17000.0             17000.0      17000.0         17000.0
# mean      -119.6      35.6                28.6       2643.7           539.4
# std          2.0       2.1                12.6       2179.9           421.5
# min       -124.3      32.5                 1.0          2.0             1.0
# 25%       -121.8      33.9                18.0       1462.0           297.0
# 50%       -118.5      34.2                29.0       2127.0           434.0
# 75%       -118.0      37.7                37.0       3151.2           648.2
# max       -114.3      42.0                52.0      37937.0          6445.0
#
#        population  households  median_income  median_house_value
# count     17000.0     17000.0        17000.0             17000.0
# mean       1429.6       501.2            3.9            207300.9
# std        1147.9       384.5            1.9            115983.8
# min           3.0         1.0            0.5             14999.0
# 25%         790.0       282.0            2.6            119400.0
# 50%        1167.0       409.0            3.5            180400.0
# 75%        1721.0       605.2            4.8            265000.0
# max       35682.0      6082.0           15.0            500001.0

# %% [markdown]
# Now, split the data into two parts -- training and evaluation.

# %%
np.random.seed(seed=1) #makes result reproducible
msk = np.random.rand(len(df)) < 0.8
traindf = df[msk]
evaldf = df[~msk]

# %% [markdown]
# ## Training and Evaluation
#
# In this exercise, we'll be trying to predict **median_house_value** It will be our label (sometimes also called a target).
#
# We'll modify the feature_cols and input function to represent the features you want to use.
#
# We divide **total_rooms** by **households** to get **avg_rooms_per_house** which we excect to positively correlate with **median_house_value**.
#
# We also divide **population** by **total_rooms** to get **avg_persons_per_room** which we expect to negatively correlate with **median_house_value**.

# %%
def add_more_features(df):
  df['avg_rooms_per_house'] = df['total_rooms'] / df['households'] #expect positive correlation
  df['avg_persons_per_room'] = df['population'] / df['total_rooms'] #expect negative correlation
  return df

# %%
# Create pandas input function
def make_input_fn(df, num_epochs):
  return tf.estimator.inputs.pandas_input_fn(
    x = add_more_features(df),
    y = df['median_house_value'] / 100000, # will talk about why later in the course
    batch_size = 128,
    num_epochs = num_epochs,
    shuffle = True,
    queue_capacity = 1000,
    num_threads = 1
  )

# %%
# Define your feature columns
def create_feature_cols():
  return [
    tf.feature_column.numeric_column('housing_median_age'),
    tf.feature_column.bucketized_column(tf.feature_column.numeric_column('latitude'), boundaries = np.arange(32.0, 42, 1).tolist()),
    tf.feature_column.numeric_column('avg_rooms_per_house'),
    tf.feature_column.numeric_column('avg_persons_per_room'),
    tf.feature_column.numeric_column('median_income')
  ]

# %%
# Create estimator train and evaluate function
def train_and_evaluate(output_dir, num_train_steps):
  estimator = tf.estimator.LinearRegressor(model_dir = output_dir, feature_columns = create_feature_cols())
  train_spec = tf.estimator.TrainSpec(input_fn = make_input_fn(traindf, None), 
                                      max_steps = num_train_steps)
  eval_spec = tf.estimator.EvalSpec(input_fn = make_input_fn(evaldf, 1), 
                                    steps = None, 
                                    start_delay_secs = 1, # start evaluating after N seconds, 
                                    throttle_secs = 5)  # evaluate every N seconds
  tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)

# %%
# Launch tensorboard
from google.datalab.ml import TensorBoard

OUTDIR = './trained_model'
TensorBoard().start(OUTDIR)
# Out:
# <p>TensorBoard was started successfully with pid 2907. Click <a href="/_proxy/52597/" target="_blank">here</a> to access it.</p>
# 2907

# %%
# Run the model
shutil.rmtree(OUTDIR, ignore_errors = True)
train_and_evaluate(OUTDIR, 2000)
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_train_distribute': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f60d62d2d50>, '_evaluation_master': '', '_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_model_dir': './trained_model', '_global_id_in_cluster': 0, '_save_summary_steps': 100}
# /usr/local/envs/py2env/lib/python2.7/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/local/envs/py2env/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 5 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into ./trained_model/model.ckpt.
# INFO:tensorflow:loss = 502.27484, step = 1
# INFO:tensorflow:global_step/sec: 249.935
# INFO:tensorflow:loss = 73.856766, step = 101 (0.405 sec)
# INFO:tensorflow:global_step/sec: 299.73
# INFO:tensorflow:loss = 67.94525, step = 201 (0.333 sec)
# INFO:tensorflow:global_step/sec: 312.081
# INFO:tensorflow:loss = 77.70708, step = 301 (0.321 sec)
# INFO:tensorflow:global_step/sec: 305.554
# INFO:tensorflow:loss = 75.59179, step = 401 (0.326 sec)
# INFO:tensorflow:global_step/sec: 280.709
# INFO:tensorflow:loss = 70.375244, step = 501 (0.357 sec)
# INFO:tensorflow:global_step/sec: 292.539
# INFO:tensorflow:loss = 45.055244, step = 601 (0.341 sec)
# INFO:tensorflow:global_step/sec: 303.124
# INFO:tensorflow:loss = 34.643745, step = 701 (0.330 sec)
# INFO:tensorflow:global_step/sec: 285.282
# INFO:tensorflow:loss = 67.966415, step = 801 (0.351 sec)
# INFO:tensorflow:global_step/sec: 289.312
# INFO:tensorflow:loss = 67.00166, step = 901 (0.346 sec)
# INFO:tensorflow:global_step/sec: 283.673
# INFO:tensorflow:loss = 158.63979, step = 1001 (0.352 sec)
# INFO:tensorflow:global_step/sec: 294.208
# INFO:tensorflow:loss = 97.751785, step = 1101 (0.340 sec)
# INFO:tensorflow:global_step/sec: 286.645
# INFO:tensorflow:loss = 51.6313, step = 1201 (0.349 sec)
# INFO:tensorflow:Saving checkpoints for 1249 into ./trained_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 70.9427.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-04-03:10:34
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/model.ckpt-1249
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-04-03:10:34
# INFO:tensorflow:Saving dict for global step 1249: average_loss = 0.73596615, global_step = 1249, loss = 92.35013
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/model.ckpt-1249
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1250 into ./trained_model/model.ckpt.
# INFO:tensorflow:loss = 89.54248, step = 1250
# INFO:tensorflow:global_step/sec: 241.264
# INFO:tensorflow:loss = 78.10009, step = 1350 (0.418 sec)
# INFO:tensorflow:global_step/sec: 307.967
# INFO:tensorflow:loss = 68.27405, step = 1450 (0.325 sec)
# INFO:tensorflow:global_step/sec: 307.125
# INFO:tensorflow:loss = 96.3265, step = 1550 (0.326 sec)
# INFO:tensorflow:global_step/sec: 279.955
# INFO:tensorflow:loss = 73.4308, step = 1650 (0.358 sec)
# INFO:tensorflow:global_step/sec: 298.663
# INFO:tensorflow:loss = 50.9535, step = 1750 (0.334 sec)
# INFO:tensorflow:global_step/sec: 293.581
# INFO:tensorflow:loss = 60.399002, step = 1850 (0.341 sec)
# INFO:tensorflow:global_step/sec: 285.998
# INFO:tensorflow:loss = 55.010307, step = 1950 (0.349 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into ./trained_model/model.ckpt.
# INFO:tensorflow:Loss for final step: 38.5822.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-12-04-03:10:38
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_model/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-12-04-03:10:39
# INFO:tensorflow:Saving dict for global step 2000: average_loss = 0.6703792, global_step = 2000, loss = 84.12018
