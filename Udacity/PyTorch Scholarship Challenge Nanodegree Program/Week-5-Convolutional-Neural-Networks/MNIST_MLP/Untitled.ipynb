# %%
import numpy as npmp

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-eb42ca6e4af3> in <module>
# ----> 1 import torch
#
# ImportError: No module named 'torch'

# %%
import torch

# %%
torch.version.cuda
# Out:
# '9.0.176'
