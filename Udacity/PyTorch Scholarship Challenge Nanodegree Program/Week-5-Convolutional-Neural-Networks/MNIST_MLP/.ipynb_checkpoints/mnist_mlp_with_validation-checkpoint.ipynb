# %%
import torch
import numpy as np

# %% [markdown]
# ### Load and Visualize the Data

# %%
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 20
# percentage of training set to use as validation
valid_size = 0.2

# conver data to torch.FloatTensor
transform = transforms.ToTensor()

# choose the train and test datasets
train_data = datasets.MNIST(root='data', train=True, download=True, transform=transform)
test_data = datasets.MNIST(root='data', train=False, download=True, transform=transform)

# obtain training indices that will be used for validation
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# prepare data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, num_workers=num_workers)

# %% [markdown]
# ### Visualize a Batch of Training Data

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title(str(labels[idx].item()))

# %%
img = np.squeeze(images[1])

fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111)
ax.imshow(img, cmap='gray')
width, height = img.shape
thresh = img.max()/2.5
for x in range(width):
    for y in range(height):
        val = round(img[x][y], 2) if img[x][y] != 0 else 0
        ax.annotate(str(val), xy=(y, x), horizontalalignment='center', verticalalignment='center', 
                    color='white' if img[x][y] < thresh else 'black')

# %% [markdown]
# ### Define the network Architecture

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the NN architecture
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # number of hidden nodes in each layer 512
        hidden_1 = 512
        hidden_2 = 512
        # linear layer (784 -> hidden_1)
        self.fc1 = nn.Linear(28 * 28, hidden_1)
        # linear layer (hidden_1 -> hidden_2)
        self.fc2 = nn.Linear(hidden_1, hidden_2)
        # linear layer (hidden_2 -> 10)
        self.fc3 = nn.Linear(hidden_2, 10)
        # dropout layer (p=0.2)
        self.dropout = nn.Dropout(0.2)
        
    def forward(self, x):
        # flatten image input
        x = x.view(-1, 28 * 28)
        # add hidden layer, with relu activation function
        x = F.relu(self.fc1(x))
        # add droupout layer
        x = self.dropout(x)
        # add hidden layer with relu activation function
        x = F.relu(self.fc2(x))
        # add dropout layer
        x = self.dropout(x)
        # add output layer
        x = self.fc3(x)
        return x
    
# initialize the NN
model = Net()
print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=10, bias=True)
#   (dropout): Dropout(p=0.2)
# )

# %% [markdown]
# ### Specify Loss Function and Optimizer

# %%
# specify loss function
criterion = nn.CrossEntropyLoss()

# specify optimizer (stochastic gradient descent) and learning rate = 0.01
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# ### Train the Network

# %%
n_epochs = 50

# initialize tracker for minimum validation loss
valid_loss_min = np.Inf # set initial "min" to infinity

for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    valid_loss = 0.0
    
    model.train()
    for data, target in train_loader:
        optimizer.zero_grad()
        # forward pass
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # backward pass
        loss.backward()
        # perform a single optimization step
        optimizer.step()
        # update running training loss
        train_loss += loss.item() * data.size(0)
        
    model.eval()
    for data, target in valid_loader:
        # forward pass
        output = model(data)
        # calculate loss
        loss = criterion(output, target)
        valid_loss += loss.item() * data.size(0)
        
    # print training / validation statistics
    # calculate average loss over an epoch
    train_loss = train_loss / len(train_loader.dataset)
    valid_loss = valid_loss / len(valid_loader.dataset)
    
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(epoch+1, train_loss, valid_loss))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}). Saving model ...'.format(valid_loss_min, valid_loss))
        torch.save(model.state_dict(), 'model.pt')
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.768203 	Validation Loss: 0.076329
# Validation loss decreased (inf --> 0.076329). Saving model ...
# Epoch: 2 	Training Loss: 0.286966 	Validation Loss: 0.058989
# Validation loss decreased (0.076329 --> 0.058989). Saving model ...
# Epoch: 3 	Training Loss: 0.224899 	Validation Loss: 0.047453
# Validation loss decreased (0.058989 --> 0.047453). Saving model ...
# Epoch: 4 	Training Loss: 0.185337 	Validation Loss: 0.040150
# Validation loss decreased (0.047453 --> 0.040150). Saving model ...
# Epoch: 5 	Training Loss: 0.158082 	Validation Loss: 0.034962
# Validation loss decreased (0.040150 --> 0.034962). Saving model ...
# Epoch: 6 	Training Loss: 0.136720 	Validation Loss: 0.031214
# Validation loss decreased (0.034962 --> 0.031214). Saving model ...
# Epoch: 7 	Training Loss: 0.121666 	Validation Loss: 0.028149
# Validation loss decreased (0.031214 --> 0.028149). Saving model ...
# Epoch: 8 	Training Loss: 0.108923 	Validation Loss: 0.026108
# Validation loss decreased (0.028149 --> 0.026108). Saving model ...
# Epoch: 9 	Training Loss: 0.097682 	Validation Loss: 0.023988
# Validation loss decreased (0.026108 --> 0.023988). Saving model ...
# Epoch: 10 	Training Loss: 0.088137 	Validation Loss: 0.022293
# Validation loss decreased (0.023988 --> 0.022293). Saving model ...
# Epoch: 11 	Training Loss: 0.079840 	Validation Loss: 0.020978
# Validation loss decreased (0.022293 --> 0.020978). Saving model ...
# Epoch: 12 	Training Loss: 0.074440 	Validation Loss: 0.019595
# Validation loss decreased (0.020978 --> 0.019595). Saving model ...
# Epoch: 13 	Training Loss: 0.069184 	Validation Loss: 0.019246
# Validation loss decreased (0.019595 --> 0.019246). Saving model ...
# Epoch: 14 	Training Loss: 0.062994 	Validation Loss: 0.018208
# Validation loss decreased (0.019246 --> 0.018208). Saving model ...
# Epoch: 15 	Training Loss: 0.059901 	Validation Loss: 0.018222
# Epoch: 16 	Training Loss: 0.055620 	Validation Loss: 0.017441
# Validation loss decreased (0.018208 --> 0.017441). Saving model ...
# Epoch: 17 	Training Loss: 0.051771 	Validation Loss: 0.017267
# Validation loss decreased (0.017441 --> 0.017267). Saving model ...
# Epoch: 18 	Training Loss: 0.048424 	Validation Loss: 0.016166
# Validation loss decreased (0.017267 --> 0.016166). Saving model ...
# Epoch: 19 	Training Loss: 0.045168 	Validation Loss: 0.015947
# Validation loss decreased (0.016166 --> 0.015947). Saving model ...
# Epoch: 20 	Training Loss: 0.042565 	Validation Loss: 0.015460
# Validation loss decreased (0.015947 --> 0.015460). Saving model ...
# Epoch: 21 	Training Loss: 0.039546 	Validation Loss: 0.015294
# Validation loss decreased (0.015460 --> 0.015294). Saving model ...
# Epoch: 22 	Training Loss: 0.038526 	Validation Loss: 0.015168
# Validation loss decreased (0.015294 --> 0.015168). Saving model ...
# Epoch: 23 	Training Loss: 0.035458 	Validation Loss: 0.014850
# Validation loss decreased (0.015168 --> 0.014850). Saving model ...
# Epoch: 24 	Training Loss: 0.033652 	Validation Loss: 0.014686
# Validation loss decreased (0.014850 --> 0.014686). Saving model ...
# Epoch: 25 	Training Loss: 0.031698 	Validation Loss: 0.014532
# Validation loss decreased (0.014686 --> 0.014532). Saving model ...
# Epoch: 26 	Training Loss: 0.030575 	Validation Loss: 0.014335
# Validation loss decreased (0.014532 --> 0.014335). Saving model ...
# Epoch: 27 	Training Loss: 0.028756 	Validation Loss: 0.014277
# Validation loss decreased (0.014335 --> 0.014277). Saving model ...
# Epoch: 28 	Training Loss: 0.027279 	Validation Loss: 0.014301
# Epoch: 29 	Training Loss: 0.026096 	Validation Loss: 0.014055
# Validation loss decreased (0.014277 --> 0.014055). Saving model ...
# Epoch: 30 	Training Loss: 0.024313 	Validation Loss: 0.013846
# Validation loss decreased (0.014055 --> 0.013846). Saving model ...
# Epoch: 31 	Training Loss: 0.023638 	Validation Loss: 0.013736
# Validation loss decreased (0.013846 --> 0.013736). Saving model ...
# Epoch: 32 	Training Loss: 0.022872 	Validation Loss: 0.013739
# Epoch: 33 	Training Loss: 0.021370 	Validation Loss: 0.013596
# Validation loss decreased (0.013736 --> 0.013596). Saving model ...
# Epoch: 34 	Training Loss: 0.019747 	Validation Loss: 0.013691
# Epoch: 35 	Training Loss: 0.019401 	Validation Loss: 0.013730
# Epoch: 36 	Training Loss: 0.018214 	Validation Loss: 0.013533
# Validation loss decreased (0.013596 --> 0.013533). Saving model ...
# Epoch: 37 	Training Loss: 0.016999 	Validation Loss: 0.013781
# Epoch: 38 	Training Loss: 0.016641 	Validation Loss: 0.013620
# Epoch: 39 	Training Loss: 0.015319 	Validation Loss: 0.013564
# Epoch: 40 	Training Loss: 0.015168 	Validation Loss: 0.013412
# Validation loss decreased (0.013533 --> 0.013412). Saving model ...
# Epoch: 41 	Training Loss: 0.015295 	Validation Loss: 0.013324
# Validation loss decreased (0.013412 --> 0.013324). Saving model ...
# Epoch: 42 	Training Loss: 0.014389 	Validation Loss: 0.013552
# Epoch: 43 	Training Loss: 0.014102 	Validation Loss: 0.013793
# Epoch: 44 	Training Loss: 0.012313 	Validation Loss: 0.013607
# Epoch: 45 	Training Loss: 0.012595 	Validation Loss: 0.013919
# Epoch: 46 	Training Loss: 0.012533 	Validation Loss: 0.013591
# Epoch: 47 	Training Loss: 0.011505 	Validation Loss: 0.013416
# Epoch: 48 	Training Loss: 0.011559 	Validation Loss: 0.013460
# Epoch: 49 	Training Loss: 0.011234 	Validation Loss: 0.013418
# Epoch: 50 	Training Loss: 0.010499 	Validation Loss: 0.013438

# %% [markdown]
# ### Load the Model with the Lowest Validation Loss

# %%
model.load_state_dict(torch.load('model.pt'))

# %% [markdown]
# ### Test the Trained Network

# %%
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval()
for data, target in test_loader:
    # forward pass
    output = model(data)
    loss = criterion(output, target)
    test_loss += loss.item() * data.size(0)
    # conver output probabilities to predicted loss
    _, pred = torch.max(output, 1)
    # compare predictions to true label
    correct = np.squeeze(pred.eq(target.data.view_as(pred)))
    # calculate test accuracy for each object class
    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1
        
# calculate and print avg test loss
test_loss /= len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (str(i), 100 * class_correct[i] / class_total[i], 
                                                         np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % classes[i])
        
print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (100.0 * np.sum(class_correct)/np.sum(class_total), 
                                                     np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.058895
#
# Test Accuracy of     0: 98% (970/980)
# Test Accuracy of     1: 99% (1124/1135)
# Test Accuracy of     2: 97% (1010/1032)
# Test Accuracy of     3: 98% (998/1010)
# Test Accuracy of     4: 98% (963/982)
# Test Accuracy of     5: 98% (877/892)
# Test Accuracy of     6: 98% (942/958)
# Test Accuracy of     7: 97% (1003/1028)
# Test Accuracy of     8: 97% (948/974)
# Test Accuracy of     9: 97% (986/1009)
#
# Test Accuracy (Overall): 98% (9821/10000)

# %% [markdown]
# ### Visualize Sample Test Results

# %%
# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds = torch.max(output, 1)
# prep images for display
images = images.numpy()

# plot the images in the batch along with predicted and true labels
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(20):
    ax = fig.add_subplot(2, 20/2, idx+1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(images[idx]), cmap='gray')
    ax.set_title('{} ({})'.format(str(preds[idx].item()), str(labels[idx].item())), 
                color=('green' if preds[idx] == labels[idx] else 'red'))
